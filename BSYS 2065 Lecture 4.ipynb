# %% [markdown]
# # BSYS 2065
# ## Business Systems Programming
# ### Lecture 4 Functions

# %% [markdown]
# Warning: I'm okay with you working together on assignments. I'm not okay with identical or nearly identical code submissions. This will be come more noticeable as the assignments get more complicated, but going forward, very similar code will be an academic integrity violation.

# %% [markdown]
# ## Functions
# - A function is a named sequence of statements that belong together
# - A function definition:
#       def name( parameters ):
#           statements
# - The parameters specify what the function needs to do its work
# - Use the standard indentation of four spaces
# - A function call (function invocation) makes the function run
# - docstring:
#     my_function_name.\_\_doc\_\_

# %%
# drawSquare
import turtle
def drawSquare(t, sz):
    """Make turtle t draw a square of with side sz."""
    for i in range(4):
        t.forward(sz)
        t.left(90)

wn = turtle.Screen()              # Set up the window and its attributes
wn.bgcolor("lightgreen")
alex = turtle.Turtle()            # create alex
drawSquare(alex, 50)             # Call the function to draw the square passing the actual turtle and the actual side size
drawSquare(alex, 100)
drawSquare(alex, 200)

# This is for my code to work in Jupyter, you won't need this bit.
turtle.done()

try:
    turtle.bye()
except:
    print("bye")
# Out:
# bye

# %% [markdown]
# ![image.png](attachment:d25f8598-22c8-4756-8a5e-bb5d05bd8af7.png)

# %% [markdown]
# ## Looping Functions

# %%
import turtle
def drawMulticolorSquare(t, sz):
    """Make turtle t draw a multi-colour square of sz."""
    for i in ['red','purple','hotpink','blue']:
        t.color(i)
        t.forward(sz)
        t.left(90)

wn = turtle.Screen()             # Set up the window and its attributes
wn.bgcolor("lightgreen")
tess = turtle.Turtle()           # create tess and set some attributes
tess.pensize(3)
size = 20                        # size of the smallest square

for i in range(15):
    drawMulticolorSquare(tess, size)
    size = size + 10             # increase the size for next time
    tess.forward(10)             # move tess along a little
    tess.right(18)               # and give her some extra turn



# This is for my code to work in Jupyter, you won't need this bit.
turtle.done()

try:
    turtle.bye()
except:
    print("bye")
# Out:
# bye

# %% [markdown]
# ## Functions that Return Values
#
# ![image.png](attachment:9a708082-6494-4a3d-8aef-d4d5101c64fa.png)

# %%
maxValue = max(4, 1, 17, 2, 12)
print(maxValue)
# Out:
# 17

# %% [markdown]
# ...

# %%
def square(x):
    y = x * x
    return y
    
toSquare = 10
result = square(toSquare)
print("The result of ", toSquare, " squared is ", result)
# Out:
# The result of  10  squared is  100

# %% [markdown]
# - Functions return None by default (beware of print statements)

# %% [markdown]
# ## Local Variables
# - A local variable only exists inside the function and you cannot use it outside
# - Lifetime – a local variable only exists while function is being executed

# %%
def square(x):
	    y = x * x
	    return y
	
z = square(10)
print(y)  #ERROR!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 	    return y
#       5 z = square(10)
# ----> 6 print(y)  #ERROR!
#
# NameError: name 'y' is not defined

# %% [markdown]
# ## Local and Global Scope

# %%
a = 7

def setA(value):
    a = value
    print("Inside setA, a is now", str(a))


print("Before setA, a =", str(a))

setA(42)

print("After setA a =", str(a))
# Out:
# Before setA, a = 7
# Inside setA, a is now 42
# After setA a = 7

# %% [markdown]
# Keep your local and global variables separate (use different names)

# %% [markdown]
# ## The Accumulator Pattern
# - The accumulator pattern is the pattern of iterating the updating of a variable
# - The variable is the accumulator

# %%
def square(x):
    runningTotal = 0
    for counter in range(x):
        runningTotal = runningTotal + x
    return runningTotal

toSquare = 4
squareResult = square(toSquare)
print("The result of", toSquare, "squared is", squareResult)
# Out:
# The result of 4 squared is 16

# %% [markdown]
# - Functions can call other Functions
# - Functional decomposition - breaking a problem into smaller subproblems
#
# What's the difference between a rectangle and a square?

# %%
import turtle
def drawRectangle(t, w, h):
    """Get turtle t to draw a rectangle of width w and height h."""
    for i in range(2):
        t.forward(w)
        t.left(90)
        t.forward(h)
        t.left(90)

def drawSquare(tx, sz):        # a new version of drawSquare
    drawRectangle(tx, sz, sz)

wn = turtle.Screen()             # Set up the window
wn.bgcolor("lightgreen")
tess = turtle.Turtle()           # create tess

#drawRectangle(tess, 50, 70)

drawSquare(tess, 50)


# This is for my code to work in Jupyter, you won't need this bit.
turtle.done()

try:
    turtle.bye()
except:
    print("bye")
# Out:
# bye

# %% [markdown]
# ## Generalization
# - Creating a new function gives you an opportunity to name a group of statements
# - Creating a new function can make a program smaller by eliminating repetitive code
# - Sometimes you can write functions that allow you to solve a specific problem using a more general solution

# %%
# Calculate price after tax for different items

price1 = 100
tax1 = price1 * 0.12
total1 = price1 + tax1
print("Total price of item 1:", total1)

price2 = 250
tax2 = price2 * 0.12
total2 = price2 + tax2
print("Total price of item 2:", total2)

price3 = 60
tax3 = price3 * 0.12
total3 = price3 + tax3
print("Total price of item 3:", total3)
# Out:
# Total price of item 1: 112.0
# Total price of item 2: 280.0
# Total price of item 3: 67.2

# %%
# Define a function to calculate total price with tax
def calculate_total_with_tax(price):
    tax_rate=0.12
    return price + (price * tax_rate)

# Use the function for different items
print("Total price of item 1:", calculate_total_with_tax(100))
print("Total price of item 2:", calculate_total_with_tax(250))
print("Total price of item 3:", calculate_total_with_tax(60))
# Out:
# Total price of item 1: 112.0
# Total price of item 2: 280.0
# Total price of item 3: 67.2

# %% [markdown]
# # Flow of Execution
# - Execution always begins at the first statement of the program
# - Statements are executed one at a time, in order, from top to bottom.
# - Function definitions do not alter the flow of execution of the program, but remember that statements inside the function are not executed until the function is called

# %%
def pow(b, p):
    y = b ** p
    print("y")
    return y

def square(x):
    a = pow(x, 2)
    print("a")
    return a

n = 5
print("n")
result = square(n)
print(result)
# Out:
# n
# y
# a
# 25

# %% [markdown]
# ## Using a Main Function
# Lines of main task processing can be placed inside the Main function

# %%
import turtle

def createTurtle(shape, bodyColor, outlineColor):
    '''Create a turtle of the passed shape, bodyColor and outlineColor.'''
    turt = turtle.Turtle()
    turt.shape(shape)
    turt.color(outlineColor, bodyColor)
    return turt

alex = createTurtle("turtle", "blue", "purple")

def drawRectangle(t, w, h):
    """Get turtle t to draw a rectangle of width w and height h."""
    for i in range(2):
        t.forward(w)
        t.left(90)
        t.forward(h)
        t.left(90)

wn = turtle.Screen()

def drawSquare(tx, sz):
    drawRectangle(tx, sz, sz)

wn.screensize(400,600,"lightgreen")
    
drawSquare(alex, 50)         # Call the function to draw the square
    
# This is for my code to work in Jupyter, you won't need this bit.    
turtle.done()

try:
    turtle.bye()
except:
    print("bye")

# %%
import turtle

def createTurtle(shape, bodyColor, outlineColor):
    '''Create a turtle of the passed shape, bodyColor and outlineColor.'''
    turt = turtle.Turtle()
    turt.shape(shape)
    turt.color(outlineColor, bodyColor)
    return turt

def drawRectangle(t, w, h):
    """Get turtle t to draw a rectangle of width w and height h."""
    for i in range(2):
        t.forward(w)
        t.left(90)
        t.forward(h)
        t.left(90)

def drawSquare(tx, sz):        # a new version of drawSquare
    drawRectangle(tx, sz, sz)


    
def main():                      # Define the main function
    wn = turtle.Screen()         # Set up the window and its attributes
    wn.screensize(400,600,"lightgreen")
    alex = createTurtle("turtle", "blue", "purple")      # create alex
    drawSquare(alex, 50)         # Call the function to draw the square
    

main()                           # Invoke the main function



# This is for my code to work in Jupyter, you won't need this bit.
turtle.done()
try:
    turtle.bye()
except:
    print("bye")

# %% [markdown]
# ## Program Development
#
# Incremental development - adding and testing only a small amount of code at a time
# - Start with a working skeleton program and make small incremental changes. At any point, if there is an error, you will know exactly where it is.
# - Use temporary variables to hold intermediate values so that you can easily inspect and check them.
# - Once the program is working, you might want to consolidate multiple statements into compound expressions, but only do this if it does not make the program more difficult to read.

# %% [markdown]
# ## Composition
# •	Composition - build functions by using other functions

# %%
def distance(x1, y1, x2, y2):
    '''Calculate the distance between two points defined by (x1,y1) and (x2,y2)'''
    dx = x2 - x1
    dy = y2 - y1
    dsquared = dx**2 + dy**2
    result = dsquared**0.5
    return result

def area(radius):
    '''Calculate the area of a circle for a given radius'''
    b = 3.14159 * radius**2
    return b
    
def area2(xc, yc, xp, yp):
    '''Calculate the area of a circle given the center (xc,yc) and a point on the perimeter (xp, yp)'''
    radius = distance(xc, yc, xp, yp)
    result = area(radius)
    return result

print(area2(0,0,1,1))

# %% [markdown]
# # Questions?
